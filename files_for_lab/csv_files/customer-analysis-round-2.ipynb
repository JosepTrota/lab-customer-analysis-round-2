# %%
import numpy as np
import pandas as pd
import time
from datetime import date

mca=pd.read_csv('marketing_customer_analysis.csv')

# %%
mca.shape
# Out:
# (10910, 26)

# %%
mca.describe()
# Out:
#          Unnamed: 0  Customer Lifetime Value        Income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        Monthly Premium Auto  Months Since Last Claim  \
# count          10910.000000             10277.000000
# mean              93.196059                15.149071
# std               34.442532                10.080349
# min               61.000000                 0.000000
# 25%               68.000000                 6.000000
# 50%               83.000000                14.000000
# 75%              109.000000                23.000000
# ...

# %%
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer                       10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   EmploymentStatus               10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
# ...

# %%
cols = []
for i in range(len(mca.columns)):
    
    cols.append(mca.columns[i].lower().replace(" ", "_"))
            
mca.columns=cols

# %%
mca.drop('unnamed:_0',axis=1, inplace=True)

# %%
mca.select_dtypes([np.number])
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
mca.select_dtypes([object])
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
mca.dropna()
mca.reset_index(drop=True, inplace=True)
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10279 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %%
# here is a function in order to define the most correct substitute for NaN in a column using interquartile range(IQR)

# Those are the variables that we will need to use:

outnan=[]
outout=[]
Q1= 0
Q3 = 0
IQR = 0
upper_limit = 0
lower_limit = 0

def cutoutliers(column):
    
    # in the beginning of the function, we set all the variables to their initial state so we don't get something funky later
    
    outnan=[]
    outout=[]
    Q1= 0
    Q3 = 0
    IQR = 0
    upper_limit = 0
    lower_limit = 0
    
    # Then we store all the numbers in a separate list so the NaNs don't affect the median
    
    for d in column:
        if np.isnan(d) != True:
            outnan.append(d)
    
    # Then we calculate the interquartile range
    
    Q1= column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    
    # And we define upper and lower limits. Every data out of those limits will be considered an outlier
    
    upper_limit = Q3 + 1.5 * IQR
    lower_limit = Q1 - 1.5 * IQR
    
    # Then we make a list containing only non outliers
    
    for i in outnan:
        if i is [np.number]:
            if i > lower_limit:
                if i < upper_limit:
                    outout.append(i)
    
    # Define the mean and median from the original dataset and the median for the new one
    
    omean = np.mean(outnan)
    omedian = np.median(outnan)
    outoutmean = np.mean(outout)
    
    # Lastly, we compare both stats from the original data to the new data stat: the function returns the closest one
    
    if outoutmean / omean > outoutmean / omedian:
        return omean
    else:
        return omedian
    
    
# Finally, here is a function to replace NaNs in a kinda scientific way
subst = 0
def nandeal(col):
    if col.dtype is [np.number]:
        subst = cutoutliers(col)
        for i in col:
            if np.isnan(i) == True:
                i = subst
            elif i is None:
                i = subst
            elif len(var) == 0:
                i = subst

# %%
for header in mca.columns:
    nandeal(mca[header])
mca.info()

# Kind of success. Variables months_since_last_claim and number_of_open_complaints have 10277 non null numbers.
# I don't know why. I changed the cutoutliers function to also change data if data equals None or was empty, with no effect.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10279 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %%
mca['effective_to_date'] = pd.to_datetime(mca['effective_to_date'], errors='coerce')
mca['month']=pd.DatetimeIndex(mca['effective_to_date']).month
mca['month'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
# As seen just before, we only have january and february
# So there is no filter to do
# Doing the bonus would be nice, but i went overkill with some functions and it's getting late...
# I will return here to do it if necessary!
# Best regards

# Josep
